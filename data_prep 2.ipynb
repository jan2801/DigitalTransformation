# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno
import os

# %%
data = pd.read_csv('data/Санкт-Петербург/DATTSVT.csv',index_col=False,sep='\t')
# Out:
# <ipython-input-2-42092d7f73d8>:1: DtypeWarning: Columns (3,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data/Санкт-Петербург/DATTSVT.csv',index_col=False,sep='\t')

# %%
data
# Out:
#        napr   period nastranapr       tnved  edizm     Stoim    Netto    Kol  \
# 0        ЭК  07/2021         AM  3506910000    NaN     66,53      162      0
# 1        ЭК  09/2021         BG  3506910000    NaN      89,7      0,4      0
# 2        ИМ  01/2021         BY  3506910000    NaN    240,87     2,36      0
# 3        ИМ  02/2021         BY  3506910000    NaN   1509,18   742,52      0
# 4        ЭК  02/2021         BY  3506910000    NaN    487,48   116,02      0
# ...     ...      ...        ...         ...    ...       ...      ...    ...
# 458954   ИМ  04/2021         US  8414594000  796.0    889,72    19,71      6
# 458955   ИМ  09/2021         US  8414108900  796.0   2378,34     2,52      6
# 458956   ЭК  05/2021         UZ  8414108900  796.0      2416       46      1
# 458957   ИМ  01/2021         CN  8414202000  796.0  32352,98  6692,88  41195
# 458958   ИМ  11/2021         CN  8414202000  796.0      1860      190   2000
#
#                                                    Region  \
# 0       40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1       40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 2       40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 3       40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 4       40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# ...                                                   ...
# 458954  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 458955  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 458956  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 458957  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 458958  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
#
#                                     Region_s
# 0       02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1       02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 2       02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 3       02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4       02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# ...                                      ...
# 458954  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 458955  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 458956  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 458957  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 458958  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
#
# [458959 rows x 10 columns]

# %%
pd.DataFrame(data['napr'].value_counts())
# Out:
#       napr
# ИМ  318489
# ЭК  140470

# %%
pd.DataFrame(data['tnved'].value_counts())
# Out:
#             tnved
# 3926909709   1033
# 4016930005    792
# 7326909807    770
# 8708299009    647
# 8421990008    647
# ...           ...
# 5509210000      1
# 4114101000      1
# 5405000000      1
# 2517410000      1
# 8414202000      1
#
# [14002 rows x 1 columns]

# %%
data = data.drop(['Region','Region_s'],axis=1)[data['nastranapr'].notna()]

# %%
data.loc[data['napr'] == 'ИМ']['nastranapr'].value_counts().plot.pie(y='count', figsize=(10, 10))
# Out:
# <AxesSubplot:ylabel='nastranapr'>

# %%
(pd.DataFrame(data.loc[data['napr'] == 'ИМ']['nastranapr'].value_counts()))
# Out:
#     nastranapr
# CN       32605
# BY       25886
# DE       23804
# IT       18358
# US       13469
# ..         ...
# BS           1
# VI           1
# KW           1
# SN           1
# SC           1
#
# [189 rows x 1 columns]

# %%
un_countries = pd.unique(data.loc[data['napr'] == 'ИМ']['nastranapr'])

# %%
un_countries
# Out:
# array(['BY', 'GB', 'IN', 'JP', 'CA', 'DE', 'CH', 'CN', 'CZ', 'FR', 'AT',
#        'SE', 'ID', 'US', 'IT', 'FI', 'ES', 'HU', 'IL', 'KZ', 'NL', 'BE',
#        'LT', 'TR', 'PL', 'KR', 'MY', 'EE', 'GR', 'NG', 'TH', 'UA', 'LV',
#        'DK', 'AU', 'IE', 'AR', 'VN', 'SI', 'TW', 'EU', 'PT', 'NO', 'SM',
#        'LB', 'BR', 'SG', 'HR', 'LK', 'MX', 'EG', 'RO', 'OM', 'AE', 'SK',
#        'NNN', 'RS', 'MC', 'PE', 'ZA', 'BG', 'SA', 'MG', 'LU', 'PH', 'CR',
#        'HK', 'KG', 'NZ', 'BA', 'CI', 'SO', 'CL', 'UY', 'PY', 'AM', 'FO',
#        'MA', 'BO', 'EC', 'GL', 'BD', 'MR', 'MU', 'CO', 'UZ', 'MD', 'GE',
#        'KE', 'PK', 'MK', 'MW', 'MZ', 'TM', 'AZ', 'TZ', 'ZM', 'ZW', 'DO',
#        'TN', 'AB', 'GT', 'NP', 'GH', 'ET', 'NI', 'SZ', 'IS', 'KH', 'DZ',
#        'HN', 'PG', 'SV', 'TJ', 'UG', 'SD', 'RW', 'MT', 'BH', 'MM', 'ER',
#        'LI', 'AL', 'CY', 'JO', 'ME', 'LA', 'HT', 'CM', 'MN', 'AD', 'VI',
#        'SL', 'ML', 'MO', 'BB', 'FK', 'TD', 'PA', 'NE', 'QA', 'MQ', 'PR',
#        'TK', 'LS', 'BM', 'DM', 'CC', 'GA', 'KP', 'JM', 'SR', 'BT', 'BI',
#        'GI', 'GM', 'PM', 'LC', 'GG', 'TT', 'YE', 'TG', 'KW', 'BN', 'PN',
#        'KN', 'SN', 'KY', 'SH', 'BS', 'SC', 'AF', 'CG', 'FJ', 'TL', 'BZ',
#        'PF', 'BV', 'CV', 'AS', 'AG', 'SB', 'PS', 'GN', 'ST', 'IR', 'VE',
#        'SY', 'CU'], dtype=object)

# %%
dict_of_cn_st = {}

# %%
for c in un_countries:
    dict_of_cn_st[c] = np.round(data['Stoim'].str.replace(',', '.').astype(float)[(data.nastranapr == c)].sum(),3)

# %%
dict_of_cn_st = {k: v for k, v in sorted(dict_of_cn_st.items(), key=lambda item: item[1])}

# %%
plt.figure(figsize=(70, 10), dpi=180)
plt.bar(list(dict_of_cn_st.keys()), dict_of_cn_st.values())
plt.show()

# %%
data.loc[data['napr'] == 'ИМ']['nastranapr'].hist(xrot=90, figsize=(20,10),grid=False,bins=len(data.loc[data['napr'] == 'ИМ']['nastranapr'].unique()),ax=()'dfd')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [233], in <cell line: 1>()
# ----> 1 data.loc[data['napr'] == 'ИМ']['nastranapr'].hist(xrot=90, figsize=(20,10),grid=False,bins=len(data.loc[data['napr'] == 'ИМ']['nastranapr'].unique()),ylabel='dfd')
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:100, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      48 """
#      49 Draw histogram of the input series using matplotlib.
#      50
#    (...)
#      97 matplotlib.axes.Axes.hist : Plot a histogram using matplotlib.
#      98 """
#      99 plot_backend = _get_plot_backend(backend)
# --> 100 return plot_backend.hist_series(
#     101     self,
#     102     by=by,
#     103     ax=ax,
#     104     grid=grid,
#     105     xlabelsize=xlabelsize,
#     106     xrot=xrot,
#     107     ylabelsize=ylabelsize,
#     108     yrot=yrot,
#     109     figsize=figsize,
#     110     bins=bins,
#     111     legend=legend,
#     112     **kwargs,
#     113 )
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:391, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, legend, **kwds)
#     389 if legend:
#     390     kwds["label"] = self.name
# --> 391 ax.hist(values, bins=bins, **kwds)
#     392 if legend:
#     393     ax.legend()
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6791, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6789 if patch:
#    6790     p = patch[0]
# -> 6791     p.update(kwargs)
#    6792     if lbl is not None:
#    6793         p.set_label(lbl)
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Rectangle' object has no property 'ylabel'

# %% [markdown]
# # Alsu     Data Preporation

# %%
dirpath = './data'
file_list = os.listdir(dirpath)

# %%
df = pd.DataFrame()
for filename in os.listdir(dirpath):
    filepath = os.path.join(dirpath, filename, 'DATTSVT.csv')
    data_new = pd.read_csv(filepath, sep='\t')
    
    df = pd.concat([df, data_new])
        
df
# Out:
# <ipython-input-34-345f7e928bda>:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_new = pd.read_csv(filepath, sep='\t')
# <ipython-input-34-345f7e928bda>:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_new = pd.read_csv(filepath, sep='\t')
# <ipython-input-34-345f7e928bda>:4: DtypeWarning: Columns (3,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_new = pd.read_csv(filepath, sep='\t')
# <ipython-input-34-345f7e928bda>:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_new = pd.read_csv(filepath, sep='\t')
# <ipython-input-34-345f7e928bda>:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_new = pd.read_csv(filepath, sep='\t')
# <ipython-input-34-345f7e928bda>:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_new = pd.read_csv(filepath, sep='\t')
# <ipython-input-34-345f7e928bda>:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_new = pd.read_csv(filepath, sep='\t')
# <ipython-input-34-345f7e928bda>:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_new = pd.read_csv(filepath, sep='\t')
# <ipython-input-34-345f7e928bda>:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_new = pd.read_csv(filepath, sep='\t')
# <ipython-input-34-345f7e928bda>:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_new = pd.read_csv(filepath, sep='\t')
# <ipython-input-34-345f7e928bda>:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_new = pd.read_csv(filepath, sep='\t')
# <ipython-input-34-345f7e928bda>:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_new = pd.read_csv(filepath, sep='\t')
# <ipython-input-34-345f7e928bda>:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_new = pd.read_csv(filepath, sep='\t')
# <ipython-input-34-345f7e928bda>:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_new = pd.read_csv(filepath, sep='\t')
# <ipython-input-34-345f7e928bda>:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_new = pd.read_csv(filepath, sep='\t')
# <ipython-input-34-345f7e928bda>:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_new = pd.read_csv(filepath, sep='\t')
#       napr   period nastranapr       tnved  edizm      Stoim   Netto Kol  \
# 0       ИМ  04/2021         US  3506100000    NaN       2475   0,816   0
# 1       ИМ  10/2021         GB  3507909000    NaN       1188    0,03   0
# 2       ИМ  08/2021         IL  3507909000    NaN        340    0,03   0
# 3       ЭК  04/2021         KZ  3808932700    NaN     268979   69120   0
# 4       ЭК  04/2021         KZ  3707100000    NaN     412,45       2   0
# ...    ...      ...        ...         ...    ...        ...     ...  ..
# 12409   ИМ  05/2021         DE  3814009000    NaN    1841,93     286   0
# 12410   ИМ  11/2021         PK  3907690000    NaN  120663,27  122800   0
# 12411   ИМ  05/2021         BY  3907690000    NaN   76242,34   81533   0
# 12412   ИМ  06/2021         CN  3907610000    NaN   50716,95   44000   0
# 12413   ИМ  05/2021         GB  3822000000    NaN     146,36   0,075   0
#
#                                 Region                          Region_s
# 0      80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1      80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 2      80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 3      80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4      80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# ...                                ...                               ...
# 12409      34000 - КОСТРОМСКАЯ ОБЛАСТЬ  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 12410      34000 - КОСТРОМСКАЯ ОБЛАСТЬ  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 12411      34000 - КОСТРОМСКАЯ ОБЛАСТЬ  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 12412      34000 - КОСТРОМСКАЯ ОБЛАСТЬ  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 12413      34000 - КОСТРОМСКАЯ ОБЛАСТЬ  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
#
# [4913026 rows x 10 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#         napr   period nastranapr       tnved  edizm      Stoim   Netto Kol  \
# 0         ИМ  04/2021         US  3506100000    NaN       2475   0,816   0
# 1         ИМ  10/2021         GB  3507909000    NaN       1188    0,03   0
# 2         ИМ  08/2021         IL  3507909000    NaN        340    0,03   0
# 3         ЭК  04/2021         KZ  3808932700    NaN     268979   69120   0
# 4         ЭК  04/2021         KZ  3707100000    NaN     412,45       2   0
# ...      ...      ...        ...         ...    ...        ...     ...  ..
# 4913021   ИМ  05/2021         DE  3814009000    NaN    1841,93     286   0
# 4913022   ИМ  11/2021         PK  3907690000    NaN  120663,27  122800   0
# 4913023   ИМ  05/2021         BY  3907690000    NaN   76242,34   81533   0
# 4913024   ИМ  06/2021         CN  3907610000    NaN   50716,95   44000   0
# 4913025   ИМ  05/2021         GB  3822000000    NaN     146,36   0,075   0
#
#                                   Region                          Region_s
# 0        80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1        80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 2        80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 3        80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4        80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# ...                                  ...                               ...
# 4913021      34000 - КОСТРОМСКАЯ ОБЛАСТЬ  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4913022      34000 - КОСТРОМСКАЯ ОБЛАСТЬ  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4913023      34000 - КОСТРОМСКАЯ ОБЛАСТЬ  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4913024      34000 - КОСТРОМСКАЯ ОБЛАСТЬ  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4913025      34000 - КОСТРОМСКАЯ ОБЛАСТЬ  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
#
# [4913026 rows x 10 columns]

# %%
df.describe()
# Out:
#               edizm
# count  1.609125e+06
# mean   7.146864e+02
# std    2.237820e+02
# min    6.000000e+00
# 25%    7.960000e+02
# 50%    7.960000e+02
# 75%    7.960000e+02
# max    8.650000e+02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4913026 entries, 0 to 4913025
# Data columns (total 10 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   napr        object
#  1   period      object
#  2   nastranapr  object
#  3   tnved       object
#  4   edizm       float64
#  5   Stoim       object
#  6   Netto       object
#  7   Kol         object
#  8   Region      object
#  9   Region_s    object
# dtypes: float64(1), object(9)
# memory usage: 374.8+ MB

# %% [markdown]
# Переведем колличественные характеристики в колонки с подходящим типом данных (числовым)

# %%
df['Stoim'] = df['Stoim'].apply(lambda x: float(x.replace(',', '.')))
type(df.Stoim[0])
# Out:
# numpy.float64

# %%
df['Netto'] = df['Netto'].apply(lambda x: float(x.replace(',', '.')))
type(df.Netto[0])
# Out:
# numpy.float64

# %%
df['Kol'] = df['Kol'].apply(lambda x: float(x.replace(',', '.')) if type(x) == str else float(x))
type(df.Kol[0])
# Out:
# numpy.float64

# %%
cols = df.columns
for col in cols:
    print(f"Характеристика: {col}")
    print(f"Количество уникальных значений: {df[col].nunique()}")
#     print(f"Список значений: {df[col]}")
#     print(df[col])
    print('///////////////////////////////////////////////////')
# Out:
# Характеристика: napr
# Количество уникальных значений: 2
# ///////////////////////////////////////////////////
# Характеристика: period
# Количество уникальных значений: 12
# ///////////////////////////////////////////////////
# Характеристика: nastranapr
# Количество уникальных значений: 244
# ///////////////////////////////////////////////////
# Характеристика: tnved
# Количество уникальных значений: 20351
# ///////////////////////////////////////////////////
# Характеристика: Stoim
# Количество уникальных значений: 2240610
# ///////////////////////////////////////////////////
# Характеристика: Netto
# Количество уникальных значений: 1328508
# ///////////////////////////////////////////////////
# Характеристика: Kol
# Количество уникальных значений: 181513
# ///////////////////////////////////////////////////
# Характеристика: Region
# Количество уникальных значений: 85
# ///////////////////////////////////////////////////
# Характеристика: Region_s
# Количество уникальных значений: 8
# ///////////////////////////////////////////////////

# %% [markdown]
# ## Data Cleaning

# %%
print('Размер выбоpки: {}, {}'.format(df.shape[0], df.shape[1]))
# Out:
# Размер выбоpки: 4913026, 10

# %% [markdown]
# Исследуем датасет на наличие пропусков

# %%
df.isna().sum()
# Out:
# napr                0
# period              0
# nastranapr        239
# tnved               0
# edizm         3303901
# Stoim               0
# Netto               0
# Kol                 0
# Region              0
# Region_s            0
# dtype: int64

# %%
df.edizm
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#            ..
# 4913021   NaN
# 4913022   NaN
# 4913023   NaN
# 4913024   NaN
# 4913025   NaN
# Name: edizm, Length: 4913026, dtype: float64

# %%
df[df.edizm.isna() == True]
# Out:
#         napr   period nastranapr       tnved  edizm      Stoim   Netto Kol  \
# 0         ИМ  04/2021         US  3506100000    NaN       2475   0,816   0
# 1         ИМ  10/2021         GB  3507909000    NaN       1188    0,03   0
# 2         ИМ  08/2021         IL  3507909000    NaN        340    0,03   0
# 3         ЭК  04/2021         KZ  3808932700    NaN     268979   69120   0
# 4         ЭК  04/2021         KZ  3707100000    NaN     412,45       2   0
# ...      ...      ...        ...         ...    ...        ...     ...  ..
# 4913021   ИМ  05/2021         DE  3814009000    NaN    1841,93     286   0
# 4913022   ИМ  11/2021         PK  3907690000    NaN  120663,27  122800   0
# 4913023   ИМ  05/2021         BY  3907690000    NaN   76242,34   81533   0
# 4913024   ИМ  06/2021         CN  3907610000    NaN   50716,95   44000   0
# 4913025   ИМ  05/2021         GB  3822000000    NaN     146,36   0,075   0
#
#                                   Region                          Region_s
# 0        80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1        80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 2        80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 3        80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4        80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# ...                                  ...                               ...
# 4913021      34000 - КОСТРОМСКАЯ ОБЛАСТЬ  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4913022      34000 - КОСТРОМСКАЯ ОБЛАСТЬ  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4913023      34000 - КОСТРОМСКАЯ ОБЛАСТЬ  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4913024      34000 - КОСТРОМСКАЯ ОБЛАСТЬ  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4913025      34000 - КОСТРОМСКАЯ ОБЛАСТЬ  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
#
# [3303901 rows x 10 columns]

# %% [markdown]
# Построим на матрицу заполненности датасета

# %%
msno.matrix(df)
# Out:
# <AxesSubplot: >

# %%
msno.bar(df)
# Out:
# <AxesSubplot: >

# %% [markdown]
# Удаляем колонку "edizm" тк она имеет большое кол-во пропусков, что ухудшит результат исследования

# %%
df = df.drop('edizm', axis=1)
df = df

# %% [markdown]
# ### nastranapr

# %% [markdown]
# Посмотрим внимательнее на пропуски в колонке "nastranapr"

# %%
df[df.nastranapr.isna() == True]
# Out:
#         napr   period nastranapr       tnved       Stoim     Netto Kol  \
# 54410     ЭК  05/2021        NaN  8402900001    18713,04      4300   0
# 167768    ЭК  02/2021        NaN  8708299009        1446        17   0
# 207883    ИМ  02/2021        NaN   806101000    46106,69   17879,5   0
# 208802    ЭК  08/2021        NaN  1001990000  3815668,75  15392100   0
# 233808    ЭК  02/2021        NaN  1001990000   4435771,7  17370980   0
# ...      ...      ...        ...         ...         ...       ...  ..
# 4682974   ИМ  12/2021        NaN  7325999009     3400,13    38,543   0
# 4690884   ИМ  08/2021        NaN  8501310000       85,57      0,02   1
# 4692139   ИМ  11/2021        NaN  8501522001     1206,23        55   2
# 4703717   ЭК  11/2021        NaN  9705000000        3340        12   0
# 4708069   ИМ  09/2021        NaN  9025198009       13,51      0,05   1
#
#                                                     Region  \
# 54410    67000 - СЕВАСТОПОЛЬ - ГОРОД ФЕДЕРАЛЬНОГО ЗНАЧЕНИЯ
# 167768                         73000 - УЛЬЯНОВСКАЯ ОБЛАСТЬ
# 207883                          03000 - КРАСНОДАРСКИЙ КРАЙ
# 208802                          03000 - КРАСНОДАРСКИЙ КРАЙ
# 233808                          03000 - КРАСНОДАРСКИЙ КРАЙ
# ...                                                    ...
# 4682974  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4690884  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4692139  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4703717  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4708069  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
#
#                                  Region_s
# 54410          03-ЮЖНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 167768   04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 207883         03-ЮЖНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 208802         03-ЮЖНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 233808         03-ЮЖНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# ...                                   ...
# 4682974  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4690884  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4692139  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4703717  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4708069  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
#
# [239 rows x 9 columns]

# %%
nastranapr_nan = df[df.nastranapr.isna() == True]

# %%
nastranapr_nan[nastranapr_nan.napr == 'ИМ']
# Out:
#         napr   period nastranapr       tnved      Stoim      Netto  Kol  \
# 207883    ИМ  02/2021        NaN   806101000   46106.69  17879.500  0.0
# 246473    ИМ  07/2021        NaN  9705000000    5995.69    100.000  0.0
# 246474    ИМ  10/2021        NaN  9705000000   18120.00    298.000  0.0
# 269738    ИМ  01/2021        NaN  0806101000   83680.80  35945.500  0.0
# 725971    ИМ  02/2021        NaN   806101000  123140.50  71539.500  0.0
# ...      ...      ...        ...         ...        ...        ...  ...
# 4623072   ИМ  08/2021        NaN  3920208000    2540.17      2.000  0.0
# 4682974   ИМ  12/2021        NaN  7325999009    3400.13     38.543  0.0
# 4690884   ИМ  08/2021        NaN  8501310000      85.57      0.020  1.0
# 4692139   ИМ  11/2021        NaN  8501522001    1206.23     55.000  2.0
# 4708069   ИМ  09/2021        NaN  9025198009      13.51      0.050  1.0
#
#                                                     Region  \
# 207883                          03000 - КРАСНОДАРСКИЙ КРАЙ
# 246473                          03000 - КРАСНОДАРСКИЙ КРАЙ
# 246474                          03000 - КРАСНОДАРСКИЙ КРАЙ
# 269738                          03000 - КРАСНОДАРСКИЙ КРАЙ
# 725971   40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# ...                                                    ...
# 4623072  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4682974  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4690884  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4692139  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4708069  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
#
#                                      Region_s
# 207883             03-ЮЖНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 246473             03-ЮЖНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 246474             03-ЮЖНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 269738             03-ЮЖНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 725971   02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# ...                                       ...
# 4623072      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4682974      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4690884      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4692139      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4708069      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
#
# [89 rows x 9 columns]

# %%
nastranapr_nan[nastranapr_nan.Stoim > 100000]
# Out:
#         napr   period nastranapr       tnved       Stoim       Netto  \
# 208802    ЭК  08/2021        NaN  1001990000  3815668.75  15392100.0
# 233808    ЭК  02/2021        NaN  1001990000  4435771.70  17370980.0
# 725971    ИМ  02/2021        NaN   806101000   123140.50     71539.5
# 870961    ИМ  12/2021        NaN   806101000   130823.74     73677.0
# 943683    ЭК  12/2021        NaN  4911990000  1340887.24      5760.0
# 950368    ИМ  01/2021        NaN   806101000   156246.17     89519.2
# 1552550   ЭК  04/2021        NaN  3102309000   359792.69   1800000.0
# 1552551   ЭК  09/2021        NaN  3102309000   271724.97   1000000.0
# 1552552   ЭК  12/2021        NaN  3102309000   826677.40   2498750.0
# 1569015   ЭК  06/2021        NaN  3102309000   307687.39   1304500.0
# 4222689   ИМ  12/2021        NaN   307119000   109973.25      7578.0
#
#               Kol                                             Region  \
# 208802        0.0                         03000 - КРАСНОДАРСКИЙ КРАЙ
# 233808        0.0                         03000 - КРАСНОДАРСКИЙ КРАЙ
# 725971        0.0  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 870961        0.0  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 943683        0.0  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 950368        0.0  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1552550  613200.0                           70000 - ТУЛЬСКАЯ ОБЛАСТЬ
# 1552551  340000.0                           70000 - ТУЛЬСКАЯ ОБЛАСТЬ
# 1552552  849575.0                           70000 - ТУЛЬСКАЯ ОБЛАСТЬ
# 1569015  444740.0                           70000 - ТУЛЬСКАЯ ОБЛАСТЬ
# 4222689       0.0  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
#
#                                      Region_s
# 208802             03-ЮЖНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 233808             03-ЮЖНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 725971   02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 870961   02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 943683   02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 950368   02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1552550      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1552551      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1552552      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1569015      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4222689      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ

# %% [markdown]
# Оставим данные по импрорту и экспорту с большими значениями стоимости, тк они могут внести существенный вклад в статистику

# %%
# df = df.dropna()
df = pd.concat([df, nastranapr_nan[nastranapr_nan.Stoim > 100000]])
df
# Out:
#         napr   period nastranapr       tnved      Stoim        Netto  \
# 0         ИМ  04/2021         US  3506100000    2475.00        0.816
# 1         ИМ  10/2021         GB  3507909000    1188.00        0.030
# 2         ИМ  08/2021         IL  3507909000     340.00        0.030
# 3         ЭК  04/2021         KZ  3808932700  268979.00    69120.000
# 4         ЭК  04/2021         KZ  3707100000     412.45        2.000
# ...      ...      ...        ...         ...        ...          ...
# 1552550   ЭК  04/2021        NaN  3102309000  359792.69  1800000.000
# 1552551   ЭК  09/2021        NaN  3102309000  271724.97  1000000.000
# 1552552   ЭК  12/2021        NaN  3102309000  826677.40  2498750.000
# 1569015   ЭК  06/2021        NaN  3102309000  307687.39  1304500.000
# 4222689   ИМ  12/2021        NaN   307119000  109973.25     7578.000
#
#               Kol                                             Region  \
# 0             0.0                    80000 - РЕСПУБЛИКА БАШКОРТОСТАН
# 1             0.0                    80000 - РЕСПУБЛИКА БАШКОРТОСТАН
# 2             0.0                    80000 - РЕСПУБЛИКА БАШКОРТОСТАН
# 3             0.0                    80000 - РЕСПУБЛИКА БАШКОРТОСТАН
# 4             0.0                    80000 - РЕСПУБЛИКА БАШКОРТОСТАН
# ...           ...                                                ...
# 1552550  613200.0                           70000 - ТУЛЬСКАЯ ОБЛАСТЬ
# 1552551  340000.0                           70000 - ТУЛЬСКАЯ ОБЛАСТЬ
# 1552552  849575.0                           70000 - ТУЛЬСКАЯ ОБЛАСТЬ
# 1569015  444740.0                           70000 - ТУЛЬСКАЯ ОБЛАСТЬ
# 4222689       0.0  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
#
#                                  Region_s
# 0        04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1        04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 2        04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 3        04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4        04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# ...                                   ...
# 1552550  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1552551  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1552552  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1569015  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4222689  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
#
# [4912798 rows x 9 columns]

# %% [markdown]
# Посмотрим как теперь изменился наш датасет

# %%
pd.DataFrame(df['napr'].value_counts())
# Out:
#        napr
# ИМ  2920056
# ЭК  1992742

# %%
pd.DataFrame(df['tnved'].value_counts())
# Out:
#             tnved
# 3926909709  13398
# 7326909807  11247
# 4016930005   9632
# 3926909709   9013
# 7326909409   8411
# ...           ...
# 4808400001      1
# 2009491100      1
# 8418610011      1
# 307879000       1
# 8901209000      1
#
# [20351 rows x 1 columns]

# %%
df.loc[df['napr'] == 'ИМ']['nastranapr'].value_counts().plot.pie(y='count', figsize=(10, 10))
# Out:
# <AxesSubplot: ylabel='nastranapr'>

# %%
df.loc[df['napr'] == 'ЭК']['nastranapr'].value_counts().plot.pie(y='count', figsize=(10, 10))
# Out:
# <AxesSubplot: ylabel='nastranapr'>

# %% [markdown]
# ### Выбросы

# %%
def calculate_outliers(data):
    q25 = data.quantile(0.25)
    q75 = data.quantile(0.75)
    iqr = q75 - q25
    boundaries = (q25 - 1.5 * iqr, q75 + 1.5 * iqr)
    
    return boundaries

# %% [markdown]
# #### Stoim

# %%
boundaries = calculate_outliers(df.Stoim)
boundaries
# Out:
# (-30619.016249999997, 51985.93375)

# %%
if df.Stoim.max() < boundaries[1]:
    print('максимум входит в границы')
else:
    print('максимум не входит в границы')
    
if df.Stoim.min() > boundaries[0]:
    print('минимум входит в границы')
else:
    print('минимум не входит в границы')
    
#Посчитаем и выведем количество выбросов
is_outlier = (df.Stoim < boundaries[0]) | (df.Stoim > boundaries[1]) 
print('количество выбросов -', is_outlier.sum())
#Посчитаем и выведем долю выбросов
print(is_outlier.sum() / len(df.Stoim))
# Out:
# максимум не входит в границы
# минимум входит в границы
# количество выбросов - 768671
# 0.15646297690236807

# %%
df[is_outlier]
# Out:
#         napr   period nastranapr       tnved      Stoim       Netto       Kol  \
# 3         ЭК  04/2021         KZ  3808932700  268979.00    69120.00       0.0
# 11        ЭК  12/2021         KZ  3907610000   67279.59    39600.00       0.0
# 12        ЭК  08/2021         KZ  3916200000  274423.55   147480.00       0.0
# 14        ИМ  07/2021         IT  3824994500   60044.09     7493.22       0.0
# 27        ЭК  05/2021         TM  3811900000  622734.37   284160.00       0.0
# ...      ...      ...        ...         ...        ...         ...       ...
# 1552550   ЭК  04/2021        NaN  3102309000  359792.69  1800000.00  613200.0
# 1552551   ЭК  09/2021        NaN  3102309000  271724.97  1000000.00  340000.0
# 1552552   ЭК  12/2021        NaN  3102309000  826677.40  2498750.00  849575.0
# 1569015   ЭК  06/2021        NaN  3102309000  307687.39  1304500.00  444740.0
# 4222689   ИМ  12/2021        NaN   307119000  109973.25     7578.00       0.0
#
#                                                     Region  \
# 3                          80000 - РЕСПУБЛИКА БАШКОРТОСТАН
# 11                         80000 - РЕСПУБЛИКА БАШКОРТОСТАН
# 12                         80000 - РЕСПУБЛИКА БАШКОРТОСТАН
# 14                         80000 - РЕСПУБЛИКА БАШКОРТОСТАН
# 27                         80000 - РЕСПУБЛИКА БАШКОРТОСТАН
# ...                                                    ...
# 1552550                           70000 - ТУЛЬСКАЯ ОБЛАСТЬ
# 1552551                           70000 - ТУЛЬСКАЯ ОБЛАСТЬ
# 1552552                           70000 - ТУЛЬСКАЯ ОБЛАСТЬ
# 1569015                           70000 - ТУЛЬСКАЯ ОБЛАСТЬ
# 4222689  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
#
#                                  Region_s
# 3        04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 11       04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 12       04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 14       04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 27       04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# ...                                   ...
# 1552550  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1552551  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1552552  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1569015  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4222689  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
#
# [768671 rows x 9 columns]

# %%
df[df.Stoim < 0]
# Out:
# Empty DataFrame
# Columns: [napr, period, nastranapr, tnved, Stoim, Netto, Kol, Region, Region_s]
# Index: []

# %%
print(df.Stoim.max())
print(df.Stoim.min())
# Out:
# 2723443497.78
# 0.0

# %%
fig, ax = plt.subplots(figsize=(5, 15))
ax.boxplot(df.Stoim)
ax.set_ylabel('Стоимость')
ax.set_title('Ящик с усами для стоимости (с аномалиями)')
# Out:
# Text(0.5, 1.0, 'Ящик с усами для стоимости (с аномалиями)')

# %% [markdown]
# Провели исследование при помощи интерквантильного исследоввания данных, а также построили график показывающй большое кол-во объектом, стоимость которых не входит в нормальное распределение

# %% [markdown]
# ### Netto

# %%
boundaries = calculate_outliers(df.Netto)
boundaries
# Out:
# (-4115.925, 6885.555)

# %%
print(df.Netto.max())
print(df.Netto.min())
# Out:
# 4764780935.0
# 0.0

# %%
if df.Netto.max() < boundaries[1]:
    print('максимум входит в границы')
else:
    print('максимум не входит в границы')
    
if df.Netto.min() > boundaries[0]:
    print('минимум входит в границы')
else:
    print('минимум не входит в границы')
    
#Посчитаем и выведем количество выбросов
is_outlier = (df.Netto < boundaries[0]) | (df.Netto > boundaries[1]) 
print('количество выбросов -', is_outlier.sum())
#Посчитаем и выведем долю выбросов
print(is_outlier.sum() / len(df.Netto))
# Out:
# максимум не входит в границы
# минимум входит в границы
# количество выбросов - 918712
# 0.18700382144757427

# %%
fig, ax = plt.subplots(figsize=(5, 15))
ax.boxplot(df.Netto)
ax.set_ylabel('Масса')
ax.set_title('Ящик с усами для стоимости (с аномалиями)')
# Out:
# Text(0.5, 1.0, 'Ящик с усами для стоимости (с аномалиями)')

# %% [markdown]
# Провели исследование при помощи интерквантильного исследоввания данных, а также построили график показывающй большое кол-во объектом, масса которых не входит в нормальное распределение

# %% [markdown]
# ### Kol

# %%
boundaries = calculate_outliers(df.Kol)
boundaries
# Out:
# (-7.5, 12.5)

# %%
print(df.Kol.max())
print(df.Kol.min())
# Out:
# 185445750000.0
# 0.0

# %%
if df.Kol.max() < boundaries[1]:
    print('максимум входит в границы')
else:
    print('максимум не входит в границы')
    
if df.Kol.min() > boundaries[0]:
    print('минимум входит в границы')
else:
    print('минимум не входит в границы')
    
#Посчитаем и выведем количество выбросов
is_outlier = (df.Kol < boundaries[0]) | (df.Kol > boundaries[1]) 
print('количество выбросов -', is_outlier.sum())
#Посчитаем и выведем долю выбросов
print(is_outlier.sum() / len(df.Kol))
# Out:
# максимум не входит в границы
# минимум входит в границы
# количество выбросов - 1056818
# 0.21511529682270675

# %%
fig, ax = plt.subplots(figsize=(5, 15))
ax.boxplot(df.Kol)
ax.set_ylabel('Масса')
ax.set_title('Ящик с усами для стоимости (с аномалиями)')
# Out:
# Text(0.5, 1.0, 'Ящик с усами для стоимости (с аномалиями)')

# %% [markdown]
# Провели исследование при помощи интерквантильного исследоввания данных, а также построили график показывающй большое кол-во объектом, кол-во которых не входит в нормальное распределение

# %%
df[is_outlier].sort_values(by='Kol').tail(15)
# Out:
#         napr   period nastranapr       tnved      Stoim      Netto  \
# 1914584   ИМ  10/2021         ES  0106490009    1990.49     20.000
# 965077    ИМ  03/2021         UA  0106900090  335817.83  10152.450
# 4514409   ИМ  01/2021         BE   106490009   65826.56    865.000
# 4181021   ИМ  02/2021         NL   106900090   18908.83    200.800
# 49834     ИМ  06/2021         ES  0106490009   10229.17     56.000
# 983485    ИМ  11/2021         ES  0106490009    3850.56     50.000
# 49448     ИМ  08/2021         GB  0106900090   31953.36   1387.510
# 1910328   ИМ  07/2021         GB  0106900090   36315.28   1444.110
# 4181026   ИМ  08/2021         NL   106900090   29645.71    196.396
# 675080    ИМ  03/2021         BE   106490009   68486.52    427.000
# 3385700   ИМ  11/2021         NL   106900090   35676.31    234.696
# 4181019   ИМ  01/2021         NL   106900090   26811.51    197.000
# 3694715   ИМ  12/2021         NL   106900090   34758.98    292.198
# 3694713   ИМ  03/2021         NL   106900090   38194.56    342.900
# 3396084   ИМ  05/2021         NL   106900090   30246.44    296.800
#
#                   Kol                                             Region  \
# 1914584  1.000002e+10                       14000 - БЕЛГОРОДСКАЯ ОБЛАСТЬ
# 965077   1.050776e+10                       14000 - БЕЛГОРОДСКАЯ ОБЛАСТЬ
# 4514409  1.081401e+10  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4181021  1.420910e+10                         46000 - МОСКОВСКАЯ ОБЛАСТЬ
# 49834    1.500070e+10                       14000 - БЕЛГОРОДСКАЯ ОБЛАСТЬ
# 983485   2.000000e+10                       14000 - БЕЛГОРОДСКАЯ ОБЛАСТЬ
# 49448    2.422620e+10                       14000 - БЕЛГОРОДСКАЯ ОБЛАСТЬ
# 1910328  3.893875e+10                       14000 - БЕЛГОРОДСКАЯ ОБЛАСТЬ
# 4181026  4.719700e+10                         46000 - МОСКОВСКАЯ ОБЛАСТЬ
# 675080   6.677476e+10  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 3385700  6.681975e+10                         46000 - МОСКОВСКАЯ ОБЛАСТЬ
# 4181019  1.232112e+11                         46000 - МОСКОВСКАЯ ОБЛАСТЬ
# 3694715  1.521882e+11                         46000 - МОСКОВСКАЯ ОБЛАСТЬ
# 3694713  1.835278e+11                         46000 - МОСКОВСКАЯ ОБЛАСТЬ
# 3396084  1.854458e+11                         46000 - МОСКОВСКАЯ ОБЛАСТЬ
#
#                                  Region_s
# 1914584  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 965077   01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4514409  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4181021  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 49834    01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 983485   01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 49448    01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1910328  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4181026  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 675080   01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 3385700  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4181019  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 3694715  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 3694713  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 3396084  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ

# %%
df[is_outlier].sort_values(by='Stoim').tail(15)
# Out:
#         napr   period nastranapr       tnved         Stoim        Netto  \
# 4924863   ЭК  10/2021         GB  7108120001  6.317942e+08    11120.046
# 4619829   ЭК  09/2021         GB  7108120001  6.588994e+08    11465.906
# 4918778   ЭК  06/2021         GB  7108120001  6.737871e+08    11358.518
# 425196    ЭК  06/2021         GB  7108120001  6.737871e+08    11358.518
# 4788176   ЭК  07/2021         GB  7108120001  6.758748e+08    11672.747
# 3944383   ИМ  11/2021         CN  8517120000  6.817774e+08  1038290.849
# 4923328   ЭК  07/2021         GB  7108120001  6.903352e+08    11944.995
# 700705    ЭК  07/2021         GB  7108120001  6.903352e+08    11944.995
# 2178683   ЭК  06/2021         GB  7108120001  7.977482e+08    13264.832
# 4570400   ИМ  12/2021         CN  8517120000  9.019182e+08  1179454.204
# 4458225   ЭК  10/2021         GB  7108120001  9.143074e+08    16076.578
# 4730743   ЭК  08/2021         GB  7108120001  9.517420e+08    16451.498
# 3406210   ЭК  03/2021         GB  7108120001  1.016593e+09    18203.901
# 2178703   ЭК  12/2021         GB  7108120001  1.094425e+09    19022.323
# 3406214   ЭК  11/2021         GB  7108120001  1.394443e+09    23491.704
#
#                 Kol                                             Region  \
# 4924863  11120045.2                        34000 - КОСТРОМСКАЯ ОБЛАСТЬ
# 4619829  11465905.4  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4918778  11358516.3                        34000 - КОСТРОМСКАЯ ОБЛАСТЬ
# 425196   11358516.3                        34000 - КОСТРОМСКАЯ ОБЛАСТЬ
# 4788176  11672744.8  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 3944383   2930658.0  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4923328  11944995.2                        34000 - КОСТРОМСКАЯ ОБЛАСТЬ
# 700705   11944995.2                        34000 - КОСТРОМСКАЯ ОБЛАСТЬ
# 2178683  13264831.8  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4570400   3105806.0  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4458225  16076578.9  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4730743  16451495.8  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 3406210  18203903.4  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 2178703  19022319.9  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 3406214  23491702.0  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
#
#                                  Region_s
# 4924863  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4619829  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4918778  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 425196   01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4788176  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 3944383  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4923328  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 700705   01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 2178683  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4570400  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4458225  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4730743  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 3406210  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 2178703  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 3406214  01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ

# %%
df[is_outlier].sort_values(by='Netto').tail(15)
# Out:
#         napr   period nastranapr       tnved         Stoim         Netto  \
# 1682123   ЭК  04/2021         FR  2711110000  9.062346e+07  6.613130e+08
# 1682122   ЭК  08/2021         FR  2711110000  1.466894e+08  6.652430e+08
# 1033416   ИМ  12/2021         KZ  2711210000  0.000000e+00  6.853077e+08
# 1034942   ИМ  05/2021         KZ  2711210000  0.000000e+00  6.903497e+08
# 1034938   ИМ  03/2021         KZ  2711210000  0.000000e+00  7.010835e+08
# 1034954   ИМ  11/2021         KZ  2711210000  0.000000e+00  7.025889e+08
# 1034936   ИМ  02/2021         KZ  2711210000  0.000000e+00  7.171061e+08
# 1034934   ИМ  01/2021         KZ  2711210000  0.000000e+00  8.009300e+08
# 2889764   ЭК  09/2021         BR  3104205000  2.431091e+08  8.010268e+08
# 1682126   ЭК  04/2021         CN  2711110000  1.467358e+08  8.033880e+08
# 1684248   ЭК  04/2021         GB  2711110000  1.363143e+08  8.082520e+08
# 583373    ЭК  10/2021         JP  2711110000  3.235388e+08  8.527689e+08
# 583372    ЭК  07/2021         JP  2711110000  3.340137e+08  1.062471e+09
# 571075    ЭК  03/2021         JP  2711110000  3.467325e+08  1.255214e+09
# 568984    ЭК  06/2021         JP  2711110000  5.638735e+08  1.858085e+09
#
#                   Kol                                             Region  \
# 1682123  1.515643e+06  71140 - ЯМАЛО-НЕНЕЦКИЙ АВТОНОМНЫЙ ОКРУГ (ТЮМЕН...
# 1682122  1.522195e+06  71140 - ЯМАЛО-НЕНЕЦКИЙ АВТОНОМНЫЙ ОКРУГ (ТЮМЕН...
# 1033416  7.959438e+08  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1034942  7.935054e+08  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1034938  8.123795e+08  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1034954  8.150683e+08  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1034936  8.290244e+08  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1034934  9.280765e+08  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 2889764  4.839038e+08                              57000 - ПЕРМСКИЙ КРАЙ
# 1682126  1.841385e+06  71140 - ЯМАЛО-НЕНЕЦКИЙ АВТОНОМНЫЙ ОКРУГ (ТЮМЕН...
# 1684248  1.852681e+06  71140 - ЯМАЛО-НЕНЕЦКИЙ АВТОНОМНЫЙ ОКРУГ (ТЮМЕН...
# 583373   1.894212e+06                        64000 - САХАЛИНСКАЯ ОБЛАСТЬ
# 583372   2.360402e+06                        64000 - САХАЛИНСКАЯ ОБЛАСТЬ
# 571075   2.788555e+06                        64000 - САХАЛИНСКАЯ ОБЛАСТЬ
# 568984   4.127143e+06                        64000 - САХАЛИНСКАЯ ОБЛАСТЬ
#
#                                      Region_s
# 1682123        05-УРАЛЬСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1682122        05-УРАЛЬСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1033416  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1034942  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1034938  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1034954  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1034936  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1034934  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 2889764      04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1682126        05-УРАЛЬСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1684248        05-УРАЛЬСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 583373   07-ДАЛЬНЕВОСТОЧНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 583372   07-ДАЛЬНЕВОСТОЧНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 571075   07-ДАЛЬНЕВОСТОЧНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 568984   07-ДАЛЬНЕВОСТОЧНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ

# %%
df.describe()
# Out:
#               Stoim         Netto           Kol
# count  4.912798e+06  4.912798e+06  4.912798e+06
# mean   1.599524e+05  2.125053e+05  2.781210e+05
# std    5.622380e+06  1.041056e+07  1.575172e+08
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.578400e+02  9.630000e+00  0.000000e+00
# 50%    2.750780e+03  1.520000e+02  0.000000e+00
# 75%    2.100908e+04  2.760000e+03  5.000000e+00
# max    2.723443e+09  4.764781e+09  1.854458e+11

# %%
df[df.Netto == 0.0].Stoim.max()
# Out:
# 1857349836.76

# %%
df[df.Netto == 0.0]
# Out:
#         napr   period nastranapr       tnved    Stoim  Netto     Kol  \
# 261217    ИМ  02/2021         AM  6203423100  1127.00    0.0  166.00
# 261452    ИМ  02/2021         AM  6204621100   383.00    0.0   46.00
# 282256    ЭК  12/2021         BG  0403101100    83.04    0.0    0.00
# 398795    ИМ  03/2021         CH  8424890009  4083.05    0.0    3.00
# 428800    ЭК  05/2021         CZ  9018908409  1443.00    0.0    2.00
# ...      ...      ...        ...         ...      ...    ...     ...
# 4797155   ИМ  04/2021         FI  2716000000  3961.96    0.0   27.02
# 4797156   ИМ  11/2021         FI  2716000000  4401.36    0.0   32.33
# 4814124   ИМ  06/2021         FI  2716000000  1280.77    0.0    8.08
# 4825022   ИМ  02/2021         FI  2716000000  7504.62    0.0   52.69
# 4825023   ИМ  09/2021         FI  2716000000  1747.80    0.0   11.77
#
#                                 Region                              Region_s
# 261217      03000 - КРАСНОДАРСКИЙ КРАЙ            03-ЮЖНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 261452      03000 - КРАСНОДАРСКИЙ КРАЙ            03-ЮЖНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 282256      03000 - КРАСНОДАРСКИЙ КРАЙ            03-ЮЖНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 398795       61000 - РЯЗАНСКАЯ ОБЛАСТЬ      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 428800       61000 - РЯЗАНСКАЯ ОБЛАСТЬ      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# ...                                ...                                   ...
# 4797155  41000 - ЛЕНИНГРАДСКАЯ ОБЛАСТЬ  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4797156  41000 - ЛЕНИНГРАДСКАЯ ОБЛАСТЬ  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4814124  41000 - ЛЕНИНГРАДСКАЯ ОБЛАСТЬ  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4825022  41000 - ЛЕНИНГРАДСКАЯ ОБЛАСТЬ  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4825023  41000 - ЛЕНИНГРАДСКАЯ ОБЛАСТЬ  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
#
# [749 rows x 9 columns]

# %%
df[df.Netto == 0.0].describe()
# Out:
#             edizm         Stoim  Netto           Kol
# count  590.000000  7.490000e+02  749.0  7.490000e+02
# mean   173.296610  1.517939e+07    0.0  2.729715e+08
# std    103.671752  7.828047e+07    0.0  6.605713e+08
# min    113.000000  0.000000e+00    0.0  0.000000e+00
# 25%    113.000000  0.000000e+00    0.0  9.440000e+00
# 50%    113.000000  1.505000e+02    0.0  4.207379e+05
# 75%    246.000000  2.634686e+06    0.0  2.254161e+08
# max    796.000000  1.857350e+09    0.0  4.898462e+09

# %%
print('Stoim = 0:', df[df.Stoim == 0.0].Stoim.count())
print('Netto = 0:', df[df.Netto == 0.0].Netto.count())
print('Kol = 0:', df[df.Kol == 0.0].Kol.count())
# Out:
# Stoim = 0: 430
# Netto = 0: 749
# Kol = 0: 3259686

# %% [markdown]
# Большие значения массы совпадают с большими значениями стоимости и количества - выделить в отдельный кластер!
#
# 0.0 в колонке Stoim, Netto - удалить (скорее всего незаполненные данные)
#
# 0.0 в колонке Kol - надо подумать

# %% [markdown]
# ### Исследуем отдельно нули в каждой колонке

# %%
df[df.Stoim == 0.]
# Out:
#         napr   period nastranapr       tnved  Stoim         Netto  \
# 376283    ЭК  04/2021         TJ  7214991000    0.0  6.869500e+04
# 927283    ЭК  12/2021         UA  8546200000    0.0  4.332000e+02
# 936407    ИМ  12/2021         US  3904692000    0.0  1.780000e+00
# 1033416   ИМ  12/2021         KZ  2711210000    0.0  6.853077e+08
# 1033417   ЭК  12/2021         KZ  2711210000    0.0  0.000000e+00
# ...      ...      ...        ...         ...    ...           ...
# 4707398   ЭК  01/2021         CH  2711210000    0.0  0.000000e+00
# 4707399   ЭК  02/2021         CH  2711210000    0.0  0.000000e+00
# 4707400   ЭК  03/2021         CH  2711210000    0.0  0.000000e+00
# 4722095   ЭК  06/2021         FR  8481309108    0.0  8.000000e-01
# 4900589   ЭК  03/2021         AM  2710192100    0.0  1.087520e+05
#
#                  Kol                                             Region  \
# 376283           0.0                        75000 - ЧЕЛЯБИНСКАЯ ОБЛАСТЬ
# 927283           0.0  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 936407           0.0  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1033416  795943849.0  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1033417  683073167.0  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# ...              ...                                                ...
# 4707398   33995451.0  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4707399   30705213.0  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4707400   33833263.0  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4722095          0.0  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4900589          0.0                   98000 - РЕСПУБЛИКА САХА (ЯКУТИЯ)
#
#                                      Region_s
# 376283         05-УРАЛЬСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 927283   02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 936407   02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1033416  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1033417  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# ...                                       ...
# 4707398      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4707399      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4707400      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4722095      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4900589  07-ДАЛЬНЕВОСТОЧНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
#
# [430 rows x 9 columns]

# %% [markdown]
# Эти значния не имеют для нас статистической значимости, удалим их

# %%
netto_0 = df[df.Netto == 0.]
netto_0_im = netto_0[netto_0.napr == 'ИМ']

# %%
netto_0[netto_0.Stoim > 1000000]
# Out:
#         napr   period nastranapr       tnved         Stoim  Netto       Kol  \
# 645607    ЭК  10/2021         FI  2716000000  2.745490e+06    0.0  45772.01
# 724481    ЭК  06/2021         FI  2716000000  4.020636e+06    0.0  71922.00
# 791278    ЭК  04/2021         FI  2716000000  1.834976e+06    0.0  50000.36
# 791279    ЭК  09/2021         FI  2716000000  3.704629e+06    0.0  44554.12
# 797954    ЭК  07/2021         FI  2716000000  6.159611e+06    0.0  80203.58
# ...      ...      ...        ...         ...           ...    ...       ...
# 4705470   ЭК  10/2021         SI  XXXXXXXXXX  1.769837e+07    0.0      0.00
# 4705471   ЭК  04/2021         SK  XXXXXXXXXX  7.741779e+07    0.0      0.00
# 4705472   ЭК  07/2021         SK  XXXXXXXXXX  1.005122e+08    0.0      0.00
# 4705477   ЭК  09/2021         AT  XXXXXXXXXX  3.136772e+08    0.0      0.00
# 4705478   ЭК  02/2021         BA  XXXXXXXXXX  3.958803e+06    0.0      0.00
#
#                                                     Region  \
# 645607   40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 724481   40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 791278   40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 791279   40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 797954   40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# ...                                                    ...
# 4705470  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4705471  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4705472  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4705477  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4705478  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
#
#                                      Region_s
# 645607   02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 724481   02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 791278   02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 791279   02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 797954   02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# ...                                       ...
# 4705470      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4705471      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4705472      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4705477      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4705478      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
#
# [213 rows x 9 columns]

# %%
netto_0_im[netto_0_im.Stoim > 100000] # оставляем!
# Out:
#         napr   period nastranapr       tnved         Stoim  Netto      Kol  \
# 1033444   ИМ  02/2021         KZ  XXXXXXXXXX  1.176386e+07    0.0     0.00
# 1033541   ИМ  01/2021         KZ  XXXXXXXXXX  1.830167e+07    0.0     0.00
# 1033543   ИМ  05/2021         KZ  XXXXXXXXXX  1.295001e+07    0.0     0.00
# 1033544   ИМ  06/2021         KZ  XXXXXXXXXX  1.179290e+07    0.0     0.00
# 1033545   ИМ  07/2021         KZ  XXXXXXXXXX  1.162841e+07    0.0     0.00
# 1033724   ИМ  11/2021         KZ  XXXXXXXXXX  1.593459e+07    0.0     0.00
# 1033782   ИМ  03/2021         KZ  XXXXXXXXXX  1.152767e+07    0.0     0.00
# 1034170   ИМ  08/2021         KZ  XXXXXXXXXX  9.497577e+06    0.0     0.00
# 3716169   ИМ  01/2021         AZ  2716000000  2.953705e+05    0.0  7158.35
# 3716171   ИМ  05/2021         AZ  2716000000  3.342710e+05    0.0  8221.70
# 3716172   ИМ  06/2021         AZ  2716000000  3.340340e+05    0.0  8339.43
# 3837963   ИМ  04/2021         AZ  2716000000  3.432686e+05    0.0  8257.42
# 4009724   ИМ  02/2021         AZ  2716000000  3.051490e+05    0.0  7519.28
# 4009726   ИМ  10/2021         AZ  2716000000  2.940831e+05    0.0  7653.54
# 4164257   ИМ  03/2021         AZ  2716000000  3.361135e+05    0.0  8263.55
# 4164259   ИМ  09/2021         AZ  2716000000  3.007389e+05    0.0  7638.89
# 4356142   ИМ  07/2021         AZ  2716000000  3.317834e+05    0.0  8278.89
# 4483719   ИМ  12/2021         AZ  2716000000  3.208288e+05    0.0  8285.75
# 4672764   ИМ  08/2021         AZ  2716000000  3.072485e+05    0.0  7649.60
# 4672765   ИМ  11/2021         AZ  2716000000  3.031990e+05    0.0  7901.40
#
#                                                     Region  \
# 1033444  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1033541  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1033543  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1033544  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1033545  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1033724  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1033782  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1034170  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 3716169  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 3716171  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 3716172  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 3837963  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4009724  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4009726  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4164257  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4164259  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4356142  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4483719  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4672764  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
# 4672765  45000 - ГОРОД МОСКВА СТОЛИЦА РОССИЙСКОЙ ФЕДЕРА...
#
#                                      Region_s
# 1033444  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1033541  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1033543  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1033544  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1033545  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1033724  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1033782  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1034170  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 3716169      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 3716171      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 3716172      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 3837963      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4009724      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4009726      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4164257      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4164259      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4356142      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4483719      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4672764      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4672765      01-ЦЕНТРАЛЬНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ

# %% [markdown]
# Оставим в выборке объекты импорта с значениями с нулевой массой, но большой стоимостью, остальные нулевые значения массы удалим

# %%
df[df.Kol == 0.]
# Out:
#         napr   period nastranapr       tnved        Stoim      Netto  Kol  \
# 0         ИМ  04/2021         US  3506100000      2475.00      0.816  0.0
# 1         ИМ  10/2021         GB  3507909000      1188.00      0.030  0.0
# 2         ИМ  08/2021         IL  3507909000       340.00      0.030  0.0
# 3         ЭК  04/2021         KZ  3808932700    268979.00  69120.000  0.0
# 4         ЭК  04/2021         KZ  3707100000       412.45      2.000  0.0
# ...      ...      ...        ...         ...          ...        ...  ...
# 1033544   ИМ  06/2021         KZ  XXXXXXXXXX  11792902.27      0.000  0.0
# 1033545   ИМ  07/2021         KZ  XXXXXXXXXX  11628412.73      0.000  0.0
# 1033724   ИМ  11/2021         KZ  XXXXXXXXXX  15934585.11      0.000  0.0
# 1033782   ИМ  03/2021         KZ  XXXXXXXXXX  11527665.77      0.000  0.0
# 1034170   ИМ  08/2021         KZ  XXXXXXXXXX   9497576.63      0.000  0.0
#
#                                                     Region  \
# 0                          80000 - РЕСПУБЛИКА БАШКОРТОСТАН
# 1                          80000 - РЕСПУБЛИКА БАШКОРТОСТАН
# 2                          80000 - РЕСПУБЛИКА БАШКОРТОСТАН
# 3                          80000 - РЕСПУБЛИКА БАШКОРТОСТАН
# 4                          80000 - РЕСПУБЛИКА БАШКОРТОСТАН
# ...                                                    ...
# 1033544  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1033545  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1033724  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1033782  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
# 1034170  40000 - ГОРОД САНКТ-ПЕТЕРБУРГ ГОРОД ФЕДЕРАЛЬНО...
#
#                                      Region_s
# 0            04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1            04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 2            04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 3            04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 4            04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# ...                                       ...
# 1033544  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1033545  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1033724  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1033782  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1034170  02-СЕВЕРО-ЗАПАДНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
#
# [3259499 rows x 9 columns]

# %% [markdown]
# Слишком большое кол-во 0 (незаполненные данных). Их нельзя восстановить или удалить полностью. Не будем рассматривать эту колонку

# %% [markdown]
# Удаление статистически незначимых данных

# %%
df = df[df.Stoim != 0.]

# %%
df = df[df.Netto != 0.]
df = pd.concat([df, netto_0_im[netto_0_im.Stoim > 100000]])

# %%
df = df.drop('Kol', axis=1)

# %%
df.shape
# Out:
# (4912007, 8)

# %% [markdown]
# ## Исследование зависимостей

# %%
df.loc[df['napr'] == 'ИМ']['nastranapr'].value_counts().plot.pie(y='count', figsize=(10, 10))
# Out:
# <AxesSubplot: ylabel='nastranapr'>

# %%
df.loc[df['napr'] == 'ИМ']['tnved'].value_counts().plot.pie(y='count', figsize=(10, 10))
# Out:
# <AxesSubplot: ylabel='tnved'>

# %%
df.head(3)
# Out:
#   napr   period nastranapr       tnved   Stoim  Netto  \
# 0   ИМ  04/2021         US  3506100000  2475.0  0.816
# 1   ИМ  10/2021         GB  3507909000  1188.0  0.030
# 2   ИМ  08/2021         IL  3507909000   340.0  0.030
#
#                             Region                          Region_s
# 0  80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1  80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 2  80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ

# %%
stats_napr_Stoim = df.groupby(['napr'], as_index=False)[['Stoim']].sum()
print(stats_napr_Stoim)
print('///////////////////')

stats_napr_Netto = df.groupby(['napr'], as_index=False)[['Netto']].sum()
print(stats_napr_Netto)
print('///////////////////')
# Out:
#   napr         Stoim
# 0   ИМ  2.934989e+11
# 1   ЭК  4.810530e+11
# ///////////////////
#   napr         Netto
# 0   ИМ  1.237537e+11
# 1   ЭК  9.131299e+11
# ///////////////////

# %%
df_im = df[df.napr == 'ИМ']
df_im.head(4)
# Out:
#   napr   period nastranapr       tnved    Stoim  Netto  \
# 0   ИМ  04/2021         US  3506100000  2475.00  0.816
# 1   ИМ  10/2021         GB  3507909000  1188.00  0.030
# 2   ИМ  08/2021         IL  3507909000   340.00  0.030
# 7   ИМ  08/2021         FR  3822000000  2022.65  2.800
#
#                             Region                          Region_s
# 0  80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 1  80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 2  80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# 7  80000 - РЕСПУБЛИКА БАШКОРТОСТАН  04-ПРИВОЛЖСКИЙ ФЕДЕРАЛЬНЫЙ ОКРУГ

# %%
stats_period_Stoim = df_im.groupby(['period'], as_index=False)[['Stoim']].sum()
print(stats_period_Stoim)
print('////////////////////////////')

stats_period_Netto = df_im.groupby(['period'], as_index=False)[['Netto']].sum()
print(stats_period_Netto)
print('////////////////////////////')
# Out:
#      period         Stoim
# 0   01/2021  1.683366e+10
# 1   02/2021  2.058003e+10
# 2   03/2021  2.497571e+10
# 3   04/2021  2.531261e+10
# 4   05/2021  2.391060e+10
# 5   06/2021  2.483599e+10
# 6   07/2021  2.542813e+10
# 7   08/2021  2.512218e+10
# 8   09/2021  2.458946e+10
# 9   10/2021  2.561294e+10
# 10  11/2021  2.682942e+10
# 11  12/2021  2.946816e+10
# ////////////////////////////
#      period         Netto
# 0   01/2021  8.227678e+09
# 1   02/2021  8.107209e+09
# 2   03/2021  1.044103e+10
# 3   04/2021  1.088377e+10
# 4   05/2021  1.086642e+10
# 5   06/2021  1.126510e+10
# 6   07/2021  1.081306e+10
# 7   08/2021  1.062652e+10
# 8   09/2021  1.044692e+10
# 9   10/2021  1.049461e+10
# 10  11/2021  1.074384e+10
# 11  12/2021  1.083758e+10
# ////////////////////////////

# %%
plt.figure(figsize=(11, 5))
plt.scatter(df_im['period'], df_im['Stoim'],)
plt.title('Зависимости стоимости от периода')
plt.ylabel('Стоимость')
plt.xlabel('период')
# Out:
# Text(0.5, 0, 'период')

# %%
plt.figure(figsize=(11, 5))
plt.scatter(df_im['period'], df_im['Netto'],)
plt.title('Зависимости массы от периода')
plt.ylabel('масса')
plt.xlabel('период')
# Out:
# Text(0.5, 0, 'период')

# %%
stats_nastranapr_Stoim = df_im.groupby(['nastranapr'], as_index=False)[['Stoim']].sum()
print(stats_nastranapr_Stoim)
print('////////////////////////////')

stats_nastranapr_Netto = df_im.groupby(['nastranapr'], as_index=False)[['Netto']].sum()
print(stats_nastranapr_Netto)
print('////////////////////////////')
# Out:
#     nastranapr         Stoim
# 0           AB  7.023239e+07
# 1           AD  4.976562e+04
# 2           AE  2.763072e+08
# 3           AF  4.722184e+06
# 4           AG  1.918170e+03
# ..         ...           ...
# 231         WF  1.185190e+03
# 232         YE  1.573317e+05
# 233         ZA  7.968769e+08
# 234         ZM  1.575014e+07
# 235         ZW  3.484610e+07
#
# [236 rows x 2 columns]
# ////////////////////////////
#     nastranapr         Netto
# 0           AB  6.722306e+07
# 1           AD  6.096535e+02
# 2           AE  6.972772e+07
# 3           AF  3.627590e+06
# 4           AG  8.372000e+01
# ..         ...           ...
# 231         WF  5.653255e+00
# 232         YE  2.161264e+04
# 233         ZA  1.316557e+09
# 234         ZM  5.104551e+06
# 235         ZW  9.454271e+06
#
# [236 rows x 2 columns]
# ////////////////////////////

# %%
df_im.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919972 entries, 0 to 4672765
# Data columns (total 8 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   napr        object
#  1   period      object
#  2   nastranapr  object
#  3   tnved       object
#  4   Stoim       float64
#  5   Netto       float64
#  6   Region      object
#  7   Region_s    object
# dtypes: float64(2), object(6)
# memory usage: 200.5+ MB

# %%
df_im[type(df_im['nastranapr']) == float]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [132], line 1
# ----> 1 df_im[type(df_im['nastranapr']) == float]
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: False

# %%
plt.figure(figsize=(55, 7))
plt.scatter(df['nastranapr'], df['Stoim'],)
plt.title('Зависимости стоимости от nastranapr')
plt.ylabel('Стоимость')
plt.xlabel('nastranapr')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [135], line 2
#       1 plt.figure(figsize=(55, 7))
# ----> 2 plt.scatter(df['nastranapr'], df['Stoim'],)
#       3 plt.title('Зависимости стоимости от nastranapr')
#       4 plt.ylabel('Стоимость')
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2778, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2773 @_copy_docstring_and_deprecators(Axes.scatter)
#    2774 def scatter(
#    2775         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2776         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2777         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2778     __ret = gca().scatter(
#    2779         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2780         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2781         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    2782         **({"data": data} if data is not None else {}), **kwargs)
#    2783     sci(__ret)
#    2784     return __ret
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:4506, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4396 """
#    4397 A scatter plot of *y* vs. *x* with varying marker size and/or color.
#    4398
#    (...)
#    4503
#    4504 """
#    4505 # Process **kwargs to handle aliases, conflicts with explicit kwargs:
# -> 4506 x, y = self._process_unit_info([("x", x), ("y", y)], kwargs)
#    4507 # np.ma.ravel yields an ndarray, not a masked array,
#    4508 # unless its argument is a masked array.
#    4509 x = np.ma.ravel(x)
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:2584, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2582     # Update from data if axis is already set but no unit is set yet.
#    2583     if axis is not None and data is not None and not axis.have_units():
# -> 2584         axis.update_units(data)
#    2585 for axis_name, axis in axis_map.items():
#    2586     # Return if no axis is set.
#    2587     if axis is None:
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/axis.py:1608, in Axis.update_units(self, data)
#    1606 neednew = self.converter != converter
#    1607 self.converter = converter
# -> 1608 default = self.converter.default_units(data, self)
#    1609 if default is not None and self.units is None:
#    1610     self.set_units(default)
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/category.py:116, in StrCategoryConverter.default_units(data, axis)
#     114 # the conversion call stack is default_units -> axis_info -> convert
#     115 if axis.units is None:
# --> 116     axis.set_units(UnitData(data))
#     117 else:
#     118     axis.units.update(data)
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/category.py:192, in UnitData.__init__(self, data)
#     190 self._counter = itertools.count()
#     191 if data is not None:
# --> 192     self.update(data)
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/category.py:227, in UnitData.update(self, data)
#     224 convertible = True
#     225 for val in OrderedDict.fromkeys(data):
#     226     # OrderedDict just iterates over unique values in data.
# --> 227     _api.check_isinstance((str, bytes), value=val)
#     228     if convertible:
#     229         # this will only be called so long as convertible is True.
#     230         convertible = self._str_is_convertible(val)
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/_api/__init__.py:93, in check_isinstance(_types, **kwargs)
#      91     names.remove("None")
#      92     names.append("None")
# ---> 93 raise TypeError(
#      94     "{!r} must be an instance of {}, not a {}".format(
#      95         k,
#      96         ", ".join(names[:-1]) + " or " + names[-1]
#      97         if len(names) > 1 else names[0],
#      98         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float

# %%
plt.figure(figsize=(55, 7))
plt.scatter(df_im['nastranapr'], df_im['Netto'],)
plt.title('Зависимости массы от nastranapr')
plt.ylabel('масса')
plt.xlabel('nastranapr')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [129], line 2
#       1 plt.figure(figsize=(55, 7))
# ----> 2 plt.scatter(df_im['nastranapr'], df_im['Netto'],)
#       3 plt.title('Зависимости массы от nastranapr')
#       4 plt.ylabel('масса')
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2778, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2773 @_copy_docstring_and_deprecators(Axes.scatter)
#    2774 def scatter(
#    2775         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2776         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2777         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2778     __ret = gca().scatter(
#    2779         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2780         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2781         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    2782         **({"data": data} if data is not None else {}), **kwargs)
#    2783     sci(__ret)
#    2784     return __ret
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:4506, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4396 """
#    4397 A scatter plot of *y* vs. *x* with varying marker size and/or color.
#    4398
#    (...)
#    4503
#    4504 """
#    4505 # Process **kwargs to handle aliases, conflicts with explicit kwargs:
# -> 4506 x, y = self._process_unit_info([("x", x), ("y", y)], kwargs)
#    4507 # np.ma.ravel yields an ndarray, not a masked array,
#    4508 # unless its argument is a masked array.
#    4509 x = np.ma.ravel(x)
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:2584, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2582     # Update from data if axis is already set but no unit is set yet.
#    2583     if axis is not None and data is not None and not axis.have_units():
# -> 2584         axis.update_units(data)
#    2585 for axis_name, axis in axis_map.items():
#    2586     # Return if no axis is set.
#    2587     if axis is None:
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/axis.py:1608, in Axis.update_units(self, data)
#    1606 neednew = self.converter != converter
#    1607 self.converter = converter
# -> 1608 default = self.converter.default_units(data, self)
#    1609 if default is not None and self.units is None:
#    1610     self.set_units(default)
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/category.py:116, in StrCategoryConverter.default_units(data, axis)
#     114 # the conversion call stack is default_units -> axis_info -> convert
#     115 if axis.units is None:
# --> 116     axis.set_units(UnitData(data))
#     117 else:
#     118     axis.units.update(data)
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/category.py:192, in UnitData.__init__(self, data)
#     190 self._counter = itertools.count()
#     191 if data is not None:
# --> 192     self.update(data)
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/category.py:227, in UnitData.update(self, data)
#     224 convertible = True
#     225 for val in OrderedDict.fromkeys(data):
#     226     # OrderedDict just iterates over unique values in data.
# --> 227     _api.check_isinstance((str, bytes), value=val)
#     228     if convertible:
#     229         # this will only be called so long as convertible is True.
#     230         convertible = self._str_is_convertible(val)
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/_api/__init__.py:93, in check_isinstance(_types, **kwargs)
#      91     names.remove("None")
#      92     names.append("None")
# ---> 93 raise TypeError(
#      94     "{!r} must be an instance of {}, not a {}".format(
#      95         k,
#      96         ", ".join(names[:-1]) + " or " + names[-1]
#      97         if len(names) > 1 else names[0],
#      98         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float

# %% [markdown]
# диаграммы для ниш (название ниши / стоимость (масса))
# разделить графики на экспорт и импорт
# посмотреть пропуски и нули:
#  -
#  -
#  -
# хороший ноутбук ()
